# %%
'''
import requests
import xml.etree.ElementTree as ET
import pandas as pd
from urllib.parse import urlparse

# Step 1: Fetch sitemap
sitemap_url = "https://www.nseindia.com/sitemap.xml"
headers = {"User-Agent": "Mozilla/5.0"}
response = requests.get(sitemap_url, headers=headers)
root = ET.fromstring(response.content)

# Step 2: Parse URLs
namespaces = {'ns': 'http://www.sitemaps.org/schemas/sitemap/0.9'}
urls = [elem.text for elem in root.findall(".//ns:loc", namespaces)]

# Step 3: Extract path and depth
data = []
for url in urls:
    parsed = urlparse(url)
    path = parsed.path.strip("/")
    depth = len(path.split("/")) if path else 0
    data.append({"url": url, "path": path, "depth": depth})

# Step 4: Create DataFrame and save to CSV
df = pd.DataFrame(data)
csv_path = "nse_sitemap_urls.csv"
df.to_csv(csv_path, index=False)

csv_path
'''

# %%
import requests
import xml.etree.ElementTree as ET
import pandas as pd
from urllib.parse import urlparse

sitemap_url = "https://www.nseindia.com/sitemap.xml"
headers = {"User-Agent": "Mozilla/5.0"}

response = requests.get(sitemap_url, headers=headers)
root = ET.fromstring(response.content)

namespaces = {'ns': 'http://www.sitemaps.org/schemas/sitemap/0.9'}
urls = [elem.text for elem in root.findall(".//ns:loc", namespaces)]

data = []
for url in urls:
    parsed = urlparse(url)
    path = parsed.path.strip("/")
    depth = len(path.split("/")) if path else 0
    data.append({"url": url, "path": path, "depth": depth})

df = pd.DataFrame(data)
df.to_csv("nse_sitemap_urls.csv", index=False)
print("Saved to nse_sitemap_urls.csv")

# %%
import requests
import xml.etree.ElementTree as ET
import pandas as pd
from urllib.parse import urlparse

# Step 1: Fetch sitemap
sitemap_url = "https://www.nseindia.com/sitemap.xml"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)",
    "Accept": "application/xml,text/html,application/xhtml+xml",
    "Referer": "https://www.nseindia.com"
}
response = requests.get(sitemap_url, headers=headers)
root = ET.fromstring(response.content)

# Step 2: Extract URLs from sitemap XML
namespaces = {'ns': 'http://www.sitemaps.org/schemas/sitemap/0.9'}
urls = [elem.text for elem in root.findall(".//ns:loc", namespaces)]

# Step 3: Build parent-child hierarchy based on last two path segments
data = []

# NEW LOOP

for url in urls:
    parsed = urlparse(url)
    path_parts = parsed.path.strip("/").split("/") if parsed.path.strip("/") else []

    parent = path_parts[-2] if len(path_parts) > 1 else ""
    child = path_parts[-1] if len(path_parts) >= 1 else ""  # '' for root path
    depth = len(path_parts)

    data.append({
        "url": url,
        "parent": parent,
        "child": child,
        "depth": depth
    })
    #old loop  
'''for url in urls:
    parsed = urlparse(url)
    path_parts = parsed.path.strip("/").split("/")
    if len(path_parts) >= 2:
        parent = path_parts[-2]
        child = path_parts[-1]
        depth = len(path_parts)
        data.append({
            "url": url,
            "parent": parent,
            "child": child,
            "depth": depth
        })'''


if len(path_parts) >= 1:
    parent = path_parts[-2] if len(path_parts) > 1 else ""
    child = path_parts[-1]



# Step 4: Create DataFrame
df = pd.DataFrame(data)
df.to_csv("nse_sitemap_urls.csv", index=False)
print("Saved to nse_sitemap_urls.csv")
# Out:
# Saved to nse_sitemap_urls.csv
