# %%
import cloudscraper
url = "https://www.nseindia.com/all-reports"


headers = {"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/132.0.0.0 Safari/537.36"}
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 import cloudscraper
#       2 url = "https://www.nseindia.com/all-reports"
#       5 headers = {"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/132.0.0.0 Safari/537.36"}
#
# ModuleNotFoundError: No module named 'cloudscraper'

# %%
scraper = cloudscraper.create_scraper()
url = "https://www.nseindia.com"

response = scraper.get(url)
print(response.status_code, response.text[:500])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 scraper = cloudscraper.create_scraper()
#       2 url = "https://www.nseindia.com"
#       4 response = scraper.get(url)
#
# NameError: name 'cloudscraper' is not defined

# %%
print(response.status_code)


#cookie = response.cookies
#print(cookie)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 print(response.status_code)
#
# NameError: name 'response' is not defined
