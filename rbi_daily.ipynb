# %%
import pandas as pd

# %%
df=pd.read_html('https://www.rbi.org.in/Scripts/BS_ViewMMO.aspx')

# %%
df[2]
# Out:
#                                         0  \
# 0                                     NaN
# 1   (Amount in ₹ crore, Rate in Per cent)
# 2                                     NaN
# 3                          MONEY MARKETS@
# 4                                     NaN
# 5      A. Overnight Segment (I+II+III+IV)
# 6                           I. Call Money
# 7                       II. Triparty Repo
# 8                        III. Market Repo
# 9              IV. Repo in Corporate Bond
# 10                        B. Term Segment
# 11                      I. Notice Money**
# 12                       II. Term Money@@
# 13                     III. Triparty Repo
# 14                        IV. Market Repo
# 15              V. Repo in Corporate Bond
#
#                                         1  \
# 0                                     NaN
# 1   (Amount in ₹ crore, Rate in Per cent)
# 2                                     NaN
# 3                                     NaN
# ...
